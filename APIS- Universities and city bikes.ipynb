# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
res = requests.get('https://raw.githubusercontent.com/Hipo/university-domains-list/master/world_universities_and_domains.json')

# %%
data = res.json()
data
# Out:
# [{'web_pages': ['http://www.marywood.edu'],
#   'name': 'Marywood University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'domains': ['marywood.edu'],
#   'country': 'United States'},
#  {'web_pages': ['https://www.upes.ac.in/'],
#   'name': 'University of Petroleum and Energy Studies',
#   'alpha_two_code': 'IN',
#   'state-province': 'Dehradun',
#   'domains': ['upes.ac.in'],
#   'country': 'India'},
#  {'web_pages': ['https://www.cstj.qc.ca',
#    'https://ccmt.cstj.qc.ca',
#    'https://ccml.cstj.qc.ca'],
#   'name': 'Cégep de Saint-Jérôme',
#   'alpha_two_code': 'CA',
#   'state-province': None,
#   'domains': ['cstj.qc.ca'],
#   'country': 'Canada'},
#  {'web_pages': ['http://www.lindenwood.edu/'],
#   'name': 'Lindenwood University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'domains': ['lindenwood.edu'],
#   'country': 'United States'},
#  {'web_pages': ['http://www.davietjal.org/'],
#   'name': 'DAV Institute of Engineering & Technology',
# ...

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#                                               web_pages  \
# 0                             [http://www.marywood.edu]
# 1                             [https://www.upes.ac.in/]
# 2     [https://www.cstj.qc.ca, https://ccmt.cstj.qc....
# 3                          [http://www.lindenwood.edu/]
# 4                           [http://www.davietjal.org/]
# ...                                                 ...
# 9777                           [https://www.oth-aw.de/]
# 9778  [https://unifatecie.edu.br/, https://ead.unifa...
# 9779                             [https://www.hamk.fi/]
# 9780                          [http://www.ktun.edu.tr/]
# 9781                          [https://uet.vnu.edu.vn/]
#
#                                                    name alpha_two_code  \
# 0                                   Marywood University             US
# 1            University of Petroleum and Energy Studies             IN
# 2                                 Cégep de Saint-Jérôme             CA
# ...

# %%
res = requests.get('http://api.citybik.es/v2/networks')

# %%
data = res.json()
data
# Out:
# {'networks': [{'company': ['ЗАО «СитиБайк»'],
#    'href': '/v2/networks/velobike-moscow',
#    'id': 'velobike-moscow',
#    'location': {'city': 'Moscow',
#     'country': 'RU',
#     'latitude': 55.75,
#     'longitude': 37.616667},
#    'name': 'Velobike'},
#   {'company': ['Gobike A/S'],
#    'href': '/v2/networks/bycyklen',
#    'id': 'bycyklen',
#    'location': {'city': 'Copenhagen',
#     'country': 'DK',
#     'latitude': 55.673582,
#     'longitude': 12.564984},
#    'name': 'Bycyklen'},
#   {'company': ['Gobike A/S'],
#    'href': '/v2/networks/nu-connect',
#    'id': 'nu-connect',
#    'location': {'city': 'Utrecht',
#     'country': 'NL',
#     'latitude': 52.117,
#     'longitude': 5.067},
#    'name': 'Nu-Connect'},
#   {'company': ['Urban Infrastructure Partner'],
#    'href': '/v2/networks/baerum-bysykkel',
#    'id': 'baerum-bysykkel',
#    'location': {'city': 'Bærum',
#     'country': 'NO',
#     'latitude': 59.89455,
#     'longitude': 10.546343},
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                                               networks
# 0    {'company': ['ЗАО «СитиБайк»'], 'href': '/v2/n...
# 1    {'company': ['Gobike A/S'], 'href': '/v2/netwo...
# 2    {'company': ['Gobike A/S'], 'href': '/v2/netwo...
# 3    {'company': ['Urban Infrastructure Partner'], ...
# 4    {'company': ['Gobike A/S'], 'href': '/v2/netwo...
# ..                                                 ...
# 544  {'company': ['Ecovelo'], 'ebikes': True, 'gbfs...
# 545  {'company': ['Ecovelo'], 'ebikes': True, 'gbfs...
# 546  {'company': ['Ecovelo'], 'ebikes': True, 'gbfs...
# 547  {'company': ['CIGL ESCH'], 'ebikes': True, 'hr...
# 548  {'company': ['Nextbike GmbH'], 'href': '/v2/ne...
#
# [549 rows x 1 columns]

# %%
df2 = json_normalize(data['networks'])
# Out:
# C:\Users\gonza\AppData\Local\Temp/ipykernel_17568/2992400220.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df2 = json_normalize(data['networks'])

# %%
df2
# Out:
#                             company                                 href  \
# 0                  [ЗАО «СитиБайк»]         /v2/networks/velobike-moscow
# 1                      [Gobike A/S]                /v2/networks/bycyklen
# 2                      [Gobike A/S]              /v2/networks/nu-connect
# 3    [Urban Infrastructure Partner]         /v2/networks/baerum-bysykkel
# 4                      [Gobike A/S]              /v2/networks/bysykkelen
# ..                              ...                                  ...
# 544                       [Ecovelo]                /v2/networks/cyclovis
# 545                       [Ecovelo]  /v2/networks/chantrerie-captainbike
# 546                       [Ecovelo]      /v2/networks/saclay-captainbike
# 547                     [CIGL ESCH]                   /v2/networks/velok
# 548                 [Nextbike GmbH]           /v2/networks/wienmobil-rad
#
#                          id                           name  \
# ...

# %% [markdown]
# Check universities in a country and the city bikes companies

# %%
country_code = input("Search you country to check universities and city bike points: ").upper()

display(df1[df1['alpha_two_code']==country_code])
display(df2[df2['location.country']==country_code])
# Out:
# Search you country to check universities and city bike points: NL
#                                               web_pages  \
# 6314                           [http://www.aucmed.edu/]
# 6315                     [http://www.eustatiusmed.edu/]
# 6316  [http://www.internationaluniversity-schoolofme...
# 6317                             [http://www.sjsm.org/]
# 6318                               [http://www.una.an/]
# 6319                               [http://www.ddu.nl/]
# 6320                [http://www.dehaagsehogeschool.nl/]
# 6321                               [http://www.eur.nl/]
# 6322                              [https://www.rsm.nl/]
# 6323           [http://www.europeanopenuniversity.com/]
# 6324                           [http://www.fontys.edu/]
# 6325             [http://www.foundationuniversity.com/]
# 6326                             [http://www.hanze.nl/]
# 6327                               [http://www.hku.nl/]
# 6328                       [http://www.hotelschool.nl/]
# ...
